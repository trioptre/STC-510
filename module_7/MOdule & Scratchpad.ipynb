# %%
# import requests
# import json
# import pandas as pd
# import praw
# from psaw import PushshiftAPI
# from datetime import datetime
# import secret

# %%
# reddit = praw.Reddit(user_agent="ASU STC-510 Data Wrangling Basics (by Trioptre)",
#                      client_id=secret.app_id,
#                      client_secret=secret.app_secret,
#                      username=secret.uname,
#                      password=secret.upass)

# %%
# early_subs = []
# for submission in reddit.subreddit('all').search('zero day', time_filter='month', limit=1000):
#     early_subs.append(submission)

# %%
import requests
import json
import pandas as pd
import praw
from datetime import datetime
import secret
import networkx as nx
import matplotlib.pyplot as plt

reddit = praw.Reddit(user_agent="ASU STC-510 Data Wrangling Basics (by Trioptre)",
                     client_id=secret.app_id,
                     client_secret=secret.app_secret,
                     username=secret.uname,
                     password=secret.upass)

search_args = {
    'q': 'zero day',
    'time_filter': 'year',
    'limit': 1000,
}

early_subs = []
for submission in reddit.subreddit('cybersecurity').search(search_args['q'], time_filter=search_args['time_filter'], limit=search_args['limit']):
    early_subs.append(submission)

# Create a list of industries and locations mentioned in the titles of the posts
industries = ['financial', 'healthcare', 'government', 'energy', 'education', 'retail', 'telecom', 'technology']
locations = ['US', 'UK', 'India', 'China', 'Russia', 'Europe', 'Asia', 'Middle East']

# Create a dictionary to hold the edges between posts, industries, and locations
edges = {}

# Iterate through each submission
for submission in early_subs:
    # Check if the title contains any of the industries
    for industry in industries:
        if industry in submission.title.lower():
            # If there is a match, add an edge between the submission and the industry
            if submission.id in edges:
                edges[submission.id].append(industry)
            else:
                edges[submission.id] = [industry]
    # Check if the title contains any of the locations
    for location in locations:
        if location in submission.title.lower():
            # If there is a match, add an edge between the submission and the location
            if submission.id in edges:
                edges[submission.id].append(location)
            else:
                edges[submission.id] = [location]

# Create a graph
G = nx.Graph()

# Add nodes for each post, industry, and location
for submission in early_subs:
    G.add_node(submission.id, type='post', title=submission.title)
for industry in industries:
    G.add_node(industry, type='industry')
for location in locations:
    G.add_node(location, type='location')

# Add edges for each post, industry, and location
for source in edges:
    for target in edges[source]:
        G.add_edge(source, target)

# Draw the graph
fig, ax = plt.subplots()
nx.draw(G, with_labels=True, ax=ax)
plt.show()

# %%
import requests
import json
import pandas as pd
import praw
from datetime import datetime
import secret
import networkx as nx
import matplotlib.pyplot as plt

reddit = praw.Reddit(user_agent="ASU STC-510 Data Wrangling Basics (by Trioptre)",
                     client_id=secret.app_id,
                     client_secret=secret.app_secret,
                     username=secret.uname,
                     password=secret.upass)

search_args = {
    'q': 'zero day',
    'time_filter': 'month',
    'limit': 1000,
}

early_subs = []
for submission in reddit.subreddit('cybersecurity').search(search_args['q'], time_filter=search_args['time_filter'], limit=search_args['limit']):
    early_subs.append(submission)

# Create a list of industries and locations mentioned in the titles of the posts
industries = ['financial', 'healthcare', 'government', 'energy', 'education', 'retail', 'telecom', 'technology']
locations = ['US', 'UK', 'India', 'China', 'Russia', 'Europe', 'Asia', 'Middle East']

# Create a dictionary to hold the edges between posts, industries, and locations
edges = {}

# Iterate through each submission
for submission in early_subs:
    # Check if the title contains any of the industries
    for industry in industries:
        if industry in submission.title.lower():
            # If there is a match, add an edge between the submission and the industry
            if submission.id in edges:
                edges[submission.id].append(industry)
            else:
                edges[submission.id] = [industry]
    # Check if the title contains any of the locations
    for location in locations:
        if location in submission.title.lower():
            # If there is a match, add an edge between the submission and the location
            if submission.id in edges:
                edges[submission.id].append(location)
            else:
                edges[submission.id] = [location]

# Create a graph
G = nx.Graph()

# Add nodes for each post, industry, and location
for submission in early_subs:
    G.add_node(submission.id, type='post', title=submission.title)
for industry in industries:
    G.add_node(industry, type='industry')
for location in locations:
    G.add_node(location, type='location')

# Add edges for each post, industry, and location
for source in edges:
    for target in edges[source]:
        G.add_edge(source, target)

# Draw the graph
pos = nx.circular_layout(G)
node_color = [G.nodes[n]['type'] for n in G.nodes]
node_size = [len(G[n]) * 50 for n in G.nodes]
edge_color = 'gray'
font_size = 10
font_color = 'black'
node_shape = 'o'

fig, ax = plt.subplots(figsize=(10, 10))
nx.draw(G, pos=pos, with_labels=True, node_color=node_color, node_size=node_size, edge_color=edge_color, font_size=font_size, font_color=font_color, node_shape=node_shape)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/urllib/request.py in _proxy_bypass_macosx_sysconf(host, proxy_settings)
#    2591                 try:
# -> 2592                     hostIP = socket.gethostbyname(hostonly)
#    2593                     hostIP = ip2num(hostIP)
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/ly/7lwb551s0m5bslxrptxmvlrc0000gn/T/ipykernel_86303/2468188401.py in <module>
#      21
#      22 early_subs = []
# ---> 23 for submission in reddit.subreddit('cybersecurity').search(search_args['q'], time_filter=search_args['time_filter'], limit=search_args['limit']):
#      24     early_subs.append(submission)
#      25
#
# ~/opt/anaconda3/lib/python3.9/site-packages/praw/models/listing/generator.py in __next__(self)
#      61
#      62         if self._listing is None or self._list_index >= len(self._listing):
# ---> 63             self._next_batch()
#      64
#      65         self._list_index += 1
#
# ~/opt/anaconda3/lib/python3.9/site-packages/praw/models/listing/generator.py in _next_batch(self)
#      87             raise StopIteration()
#      88
# ---> 89         self._listing = self._reddit.get(self.url, params=self.params)
#      90         self._listing = self._extract_sublist(self._listing)
#      91         self._list_index = 0
#
# ~/opt/anaconda3/lib/python3.9/site-packages/praw/util/deprecate_args.py in wrapped(*args, **kwargs)
#      41                     stacklevel=2,
#      42                 )
# ---> 43             return func(**dict(zip(_old_args, args)), **kwargs)
#      44
#      45         return wrapped
#
# ~/opt/anaconda3/lib/python3.9/site-packages/praw/reddit.py in get(self, path, params)
#     710
#     711         """
# --> 712         return self._objectify_request(method="GET", params=params, path=path)
#     713
#     714     @_deprecate_args("fullnames", "url", "subreddits")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/praw/reddit.py in _objectify_request(self, data, files, json, method, params, path)
#     515         """
#     516         return self._objector.objectify(
# --> 517             self.request(
#     518                 data=data,
#     519                 files=files,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/praw/util/deprecate_args.py in wrapped(*args, **kwargs)
#      41                     stacklevel=2,
#      42                 )
# ---> 43             return func(**dict(zip(_old_args, args)), **kwargs)
#      44
#      45         return wrapped
#
# ~/opt/anaconda3/lib/python3.9/site-packages/praw/reddit.py in request(self, data, files, json, method, params, path)
#     939             raise ClientException("At most one of 'data' or 'json' is supported.")
#     940         try:
# --> 941             return self._core.request(
#     942                 data=data,
#     943                 files=files,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/prawcore/sessions.py in request(self, method, path, data, files, json, params, timeout)
#     328             json["api_type"] = "json"
#     329         url = urljoin(self._requestor.oauth_url, path)
# --> 330         return self._request_with_retries(
#     331             data=data,
#     332             files=files,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/prawcore/sessions.py in _request_with_retries(self, data, files, json, method, params, timeout, url, retry_strategy_state)
#     251             or response.status_code in self.RETRY_STATUSES
#     252         ):
# --> 253             return self._do_retry(
#     254                 data,
#     255                 files,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/prawcore/sessions.py in _do_retry(self, data, files, json, method, params, response, retry_strategy_state, saved_exception, timeout, url)
#     160             status = response.status_code
#     161         log.warning(f"Retrying due to {status} status: {method} {url}")
# --> 162         return self._request_with_retries(
#     163             data=data,
#     164             files=files,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/prawcore/sessions.py in _request_with_retries(self, data, files, json, method, params, timeout, url, retry_strategy_state)
#     251             or response.status_code in self.RETRY_STATUSES
#     252         ):
# --> 253             return self._do_retry(
#     254                 data,
#     255                 files,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/prawcore/sessions.py in _do_retry(self, data, files, json, method, params, response, retry_strategy_state, saved_exception, timeout, url)
#     160             status = response.status_code
#     161         log.warning(f"Retrying due to {status} status: {method} {url}")
# --> 162         return self._request_with_retries(
#     163             data=data,
#     164             files=files,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/prawcore/sessions.py in _request_with_retries(self, data, files, json, method, params, timeout, url, retry_strategy_state)
#     226         retry_strategy_state.sleep()
#     227         self._log_request(data, method, params, url)
# --> 228         response, saved_exception = self._make_request(
#     229             data,
#     230             files,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/prawcore/sessions.py in _make_request(self, data, files, json, method, params, retry_strategy_state, timeout, url)
#     183     ):
#     184         try:
# --> 185             response = self._rate_limiter.call(
#     186                 self._requestor.request,
#     187                 self._set_header_callback,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/prawcore/rate_limit.py in call(self, request_function, set_header_callback, *args, **kwargs)
#      31         """
#      32         self.delay()
# ---> 33         kwargs["headers"] = set_header_callback()
#      34         response = request_function(*args, **kwargs)
#      35         self.update(response.headers)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/prawcore/sessions.py in _set_header_callback(self)
#     281             self._authorizer, "refresh"
#     282         ):
# --> 283             self._authorizer.refresh()
#     284         return {"Authorization": f"bearer {self._authorizer.access_token}"}
#     285
#
# ~/opt/anaconda3/lib/python3.9/site-packages/prawcore/auth.py in refresh(self)
#     423         if two_factor_code:
#     424             additional_kwargs["otp"] = two_factor_code
# --> 425         self._request_token(
#     426             grant_type="password",
#     427             username=self._username,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/prawcore/auth.py in _request_token(self, **data)
#     153         )
#     154         pre_request_time = time.time()
# --> 155         response = self._authenticator._post(url, **data)
#     156         payload = response.json()
#     157         if "error" in payload:  # Why are these OKAY responses?
#
# ~/opt/anaconda3/lib/python3.9/site-packages/prawcore/auth.py in _post(self, url, success_status, **data)
#      28
#      29     def _post(self, url, success_status=codes["ok"], **data):
# ---> 30         response = self._requestor.request(
#      31             "post",
#      32             url,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/prawcore/requestor.py in request(self, timeout, *args, **kwargs)
#      56         """Issue the HTTP request capturing any errors that may occur."""
#      57         try:
# ---> 58             return self._http.request(
#      59                 *args, timeout=timeout or self.timeout, **kwargs
#      60             )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     575         proxies = proxies or {}
#     576
# --> 577         settings = self.merge_environment_settings(
#     578             prep.url, proxies, stream, verify, cert
#     579         )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in merge_environment_settings(self, url, proxies, stream, verify, cert)
#     757             # Set environment's proxies.
#     758             no_proxy = proxies.get("no_proxy") if proxies is not None else None
# --> 759             env_proxies = get_environ_proxies(url, no_proxy=no_proxy)
#     760             for (k, v) in env_proxies.items():
#     761                 proxies.setdefault(k, v)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/utils.py in get_environ_proxies(url, no_proxy)
#     823     :rtype: dict
#     824     """
# --> 825     if should_bypass_proxies(url, no_proxy=no_proxy):
#     826         return {}
#     827     else:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/utils.py in should_bypass_proxies(url, no_proxy)
#     807         # parsed.hostname can be `None` in cases such as a file URI.
#     808         try:
# --> 809             bypass = proxy_bypass(parsed.hostname)
#     810         except (TypeError, socket.gaierror):
#     811             bypass = False
#
# ~/opt/anaconda3/lib/python3.9/urllib/request.py in proxy_bypass(host)
#    2645             return proxy_bypass_environment(host, proxies)
#    2646         else:
# -> 2647             return proxy_bypass_macosx_sysconf(host)
#    2648
#    2649     def getproxies():
#
# ~/opt/anaconda3/lib/python3.9/urllib/request.py in proxy_bypass_macosx_sysconf(host)
#    2622     def proxy_bypass_macosx_sysconf(host):
#    2623         proxy_settings = _get_proxy_settings()
# -> 2624         return _proxy_bypass_macosx_sysconf(host, proxy_settings)
#    2625
#    2626     def getproxies_macosx_sysconf():
#
# ~/opt/anaconda3/lib/python3.9/urllib/request.py in _proxy_bypass_macosx_sysconf(host, proxy_settings)
#    2590             if hostIP is None:
#    2591                 try:
# -> 2592                     hostIP = socket.gethostbyname(hostonly)
#    2593                     hostIP = ip2num(hostIP)
#    2594                 except OSError:
#
# KeyboardInterrupt:
